# %%
import torch
from transformers import BertForQuestionAnswering, BertTokenizer
import torch
import warnings
from transformers import BertForQuestionAnswering, BertTokenizer, logging

# Suppress warnings globally
warnings.filterwarnings("ignore")

# Suppress Hugging Face Transformers logging
logging.set_verbosity_error()

# Load BERT model and tokenizer
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# Function to get an answer from a short paragraph
def answer_question(question, answer_text):
    input_ids = tokenizer.encode(question, answer_text)

    sep_index = input_ids.index(tokenizer.sep_token_id)
    num_seg_a = sep_index + 1
    num_seg_b = len(input_ids) - num_seg_a
    segment_ids = [0] * num_seg_a + [1] * num_seg_b

    assert len(segment_ids) == len(input_ids)

    outputs = model(torch.tensor([input_ids]), token_type_ids=torch.tensor([segment_ids]))
    start_scores = outputs.start_logits
    end_scores = outputs.end_logits

    answer_start = torch.argmax(start_scores)
    answer_end = torch.argmax(end_scores)
    tokens = tokenizer.convert_ids_to_tokens(input_ids)

    answer = tokens[answer_start]
    for i in range(answer_start + 1, answer_end + 1):
        if tokens[i].startswith('##'):
            answer += tokens[i][2:]
        else:
            answer += ' ' + tokens[i]

    return answer

# Function to compute probability for selecting the best chunk
def answer_question_probability(question, answer_text):
    input_ids = tokenizer.encode(question, answer_text)
    sep_index = input_ids.index(tokenizer.sep_token_id)
    num_seg_a = sep_index + 1
    num_seg_b = len(input_ids) - num_seg_a
    segment_ids = [0] * num_seg_a + [1] * num_seg_b

    outputs = model(torch.tensor([input_ids]), token_type_ids=torch.tensor([segment_ids]))
    start_scores = outputs.start_logits
    end_scores = outputs.end_logits

    probability = max(start_scores.tolist()[0]) + max(end_scores.tolist()[0])
    return probability

# Function to determine best section using probability
def answer_question_longfile_probability(question, answer_text, max_num_sentences, overlap_num_sentences):
    content = answer_text.splitlines()
    len_sentence = len(content)
    piece_num = - (- (len_sentence - max_num_sentences) // (max_num_sentences - overlap_num_sentences)) + 1
    prob = [0] * piece_num

    for jj in range(piece_num):
        start_idx = (max_num_sentences - overlap_num_sentences) * jj
        end_idx = min(start_idx + max_num_sentences, len_sentence)
        content_temp = " ".join(content[start_idx:end_idx])

        prob[jj] = answer_question_probability(question, content_temp)

    max_prob = max(prob)
    max_index = prob.index(max_prob)
    return max_index

# Function for handling long paragraphs
def answer_question_longfile(question, answer_text, max_num_sentences=12, overlap_num_sentences=5):
    input_ids = tokenizer.encode(question, answer_text)

    if len(input_ids) <= 512:
        return answer_question(question, answer_text)

    max_index = answer_question_longfile_probability(question, answer_text, max_num_sentences, overlap_num_sentences)
    content = answer_text.splitlines()
    len_sentence = len(content)
    piece_num = - (- (len_sentence - max_num_sentences) // (max_num_sentences - overlap_num_sentences)) + 1

    if max_index == 0:
        content_temp = " ".join(content[:max_num_sentences])
    elif max_index == piece_num - 1:
        content_temp = " ".join(content[(max_num_sentences - overlap_num_sentences) * (piece_num - 1):])
    else:
        start_idx = (max_num_sentences - overlap_num_sentences) * max_index
        end_idx = min(start_idx + max_num_sentences, len_sentence)
        content_temp = " ".join(content[start_idx:end_idx])

    return answer_question(question, content_temp)

# %%
dataset_path = "/Users/kamalnadhkundla/Desktop/codebert/dataset5/"
import os
import pandas as pd

# Define the question
question = "What is the initial fee?"

# Store results in a DataFrame
results = []

# Process each text file in the dataset5 folder
for filename in os.listdir(dataset_path):
    if filename.endswith(".txt"):  # Ensure it's a text file
        file_path = os.path.join(dataset_path, filename)
        
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()
        
        # Generate answer
        answer = answer_question_longfile(question, text)
        
        # Store result
        results.append({"File Name": filename, "Generated Answer": answer})

# Convert results to a DataFrame
df = pd.DataFrame(results)

# %%
df
# Out:
#                                             File Name  \
# 0         15 Keller Williams.pdf-all_items_item_5.txt
# 1                      3 KFC.pdf-all_items_item_5.txt
# 2               24 Applebees.pdf-all_items_item_5.txt
# 3                  45 Zaxbys.pdf-all_items_item_5.txt
# 4            42 Jimmy John's.pdf-all_items_item_5.txt
# 5                 32 Servpro.pdf-all_items_item_5.txt
# 6          20 Sonic Drive-In.pdf-all_items_item_5.txt
# 7              46 Carl's Jr..pdf-all_items_item_5.txt
# 8          47 Baskin Robbins.pdf-all_items_item_5.txt
# 9               1 McDonald's.pdf-all_items_item_5.txt
# 10            5 Ace Hardware.pdf-all_items_item_5.txt
# 11                36 Denny's.pdf-all_items_item_5.txt
# 12         40 Paris Baguette.pdf-all_items_item_5.txt
# 13     28 Buffalo Wild Wings.pdf-all_items_item_5.txt
# 14     30 Berkshire Hathaway.pdf-all_items_item_5.txt
# 15             4 Burger King.pdf-all_items_item_5.txt
# 16             6 Chick-fil-A.pdf-all_items_item_5.txt
# 17          31 The UPS Store.pdf-all_items_item_5.txt
# 18         29 Planet Fitness.pdf-all_items_item_5.txt
# 19  25 Express Employment Professionals.pdf-all_it...
# 20              10 Taco Bell.pdf-all_items_item_5.txt
# 21        27 Jack In The Box.pdf-all_items_item_5.txt
# 22               37 Culver's.pdf-all_items_item_5.txt
# 23                 23 Arby's.PDF-all_items_item_5.txt
# 24           44 Home Instead.pdf-all_items_item_5.txt
# 25           39 Jersey Mikes.pdf-all_items_item_5.txt
# 26                14 Dunkin'.pdf-all_items_item_5.txt
# 27                  52 Midas.pdf-all_items_item_5.txt
# 28              35 Five Guys.pdf-all_items_item_5.txt
# 29            54 Homevesters.pdf-all_items_item_5.txt
# 30          49 Snap-On Tools.pdf-all_items_item_5.txt
# 31              12 Pizza Hut.pdf-all_items_item_5.txt
# 32                9 Circle K.pdf-all_items_item_5.txt
# 33                  13 REMAX.pdf-all_items_item_5.txt
# 34               41 Hardee's.pdf-all_items_item_5.txt
# 35            22 Papa John's.pdf-all_items_item_5.txt
# 36                   33 IHOP.pdf-all_items_item_5.txt
# 37  18 Popeyes Louisiana Kitchen.pdf-all_items_ite...
# 38            19 Dairy Queen.pdf-all_items_item_5.txt
# 39        50 Anytime Fitness.pdf-all_items_item_5.txt
# 40               38 Wingstop.pdf-all_items_item_5.txt
# 41                8 Domino's.pdf-all_items_item_5.txt
# 42           17 Panera Bread.pdf-all_items_item_5.txt
# 43            16 Tim Hortons.pdf-all_items_item_5.txt
# 44                11 Wendy's.pdf-all_items_item_5.txt
# 45  43 Vavoline Instant Oil Change.pdf-all_items_i...
# 46                  7 Subway.pdf-all_items_item_5.txt
# 47             51 Jiffy Lube.pdf-all_items_item_5.txt
# 48                26 Chili's.pdf-all_items_item_5.txt
# 49         21 Little Caesars.pdf-all_items_item_5.txt
#
#                                      Generated Answer
# 0                                          $ 35 , 000
# 1                                          $ 45 , 000
# 2   the same for all franchisees subject to this o...
# 3                                          $ 35 , 000
# 4   $ 5 , 000 , if you are a franchisee in good st...
# 5                                          $ 90 , 000
# 6                                    up to $ 30 , 000
# 7                                          $ 25 , 000
# 8                                          $ 12 , 500
# 9   $ 45 , 000 lump sum initial franchise fee on t...
# 10                                          $ 5 , 000
# 11                                         $ 10 , 000
# 12                             fifty thousand dollars
# 13                                         $ 45 , 000
# 14                                         $ 25 , 000
# 15                                         $ 25 , 000
# 16                   we do not refund any initial fee
# 17                                          $ 7 , 500
# 18                            $ 10 , 000 per location
# 19                                         $ 40 , 000
# 20                                         $ 22 , 500
# 21          $ 50 , 000 for each franchised restaurant
# 22                                         $ 55 , 000
# 23                                         $ 37 , 500
# 24                                         $ 54 , 000
# 25                                         $ 43 , 500
# 26                                         $ 90 , 000
# 27                                         $ 35 , 000
# 28                                         $ 25 , 000
# 29                                         $ 85 , 000
# 30                                         $ 16 , 000
# 31                                         $ 25 , 000
# 32                                         $ 25 , 000
# 33                                         $ 25 , 000
# 34                                         $ 25 , 000
# 35                            $ 5 , 000 to $ 25 , 000
# 36                                         $ 50 , 000
# 37                                         $ 50 , 000
# 38                                         $ 45 , 000
# 39                                         $ 42 , 500
# 40                                         $ 20 , 000
# 41       prior to us issuing the applicable agreement
# 42                     thirty - five thousand dollars
# 43                                         $ 25 , 000
# 44                                         $ 20 , 000
# 45                                         $ 30 , 000
# 46                         franchise fee6 , $ 1 , 000
# 47                                         $ 35 , 000
# 48                                         $ 60 , 000
# 49                                         $ 20 , 000

# %%
dataset_path = "/Users/kamalnadhkundla/Desktop/codebert/dataset5/"
import os
import pandas as pd

# Define the question
question = "How much is the initial franchise fee?"

# Store results in a DataFrame
results = []

# Process each text file in the dataset5 folder
for filename in os.listdir(dataset_path):
    if filename.endswith(".txt"):  # Ensure it's a text file
        file_path = os.path.join(dataset_path, filename)
        
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()
        
        # Generate answer
        answer = answer_question_longfile(question, text)
        
        # Store result
        results.append({"File Name": filename, "Generated Answer": answer})

# Convert results to a DataFrame
df = pd.DataFrame(results)
df
# Out:
#                                             File Name  \
# 0         15 Keller Williams.pdf-all_items_item_5.txt
# 1                      3 KFC.pdf-all_items_item_5.txt
# 2               24 Applebees.pdf-all_items_item_5.txt
# 3                  45 Zaxbys.pdf-all_items_item_5.txt
# 4            42 Jimmy John's.pdf-all_items_item_5.txt
# 5                 32 Servpro.pdf-all_items_item_5.txt
# 6          20 Sonic Drive-In.pdf-all_items_item_5.txt
# 7              46 Carl's Jr..pdf-all_items_item_5.txt
# 8          47 Baskin Robbins.pdf-all_items_item_5.txt
# 9               1 McDonald's.pdf-all_items_item_5.txt
# 10            5 Ace Hardware.pdf-all_items_item_5.txt
# 11                36 Denny's.pdf-all_items_item_5.txt
# 12         40 Paris Baguette.pdf-all_items_item_5.txt
# 13     28 Buffalo Wild Wings.pdf-all_items_item_5.txt
# 14     30 Berkshire Hathaway.pdf-all_items_item_5.txt
# 15             4 Burger King.pdf-all_items_item_5.txt
# 16             6 Chick-fil-A.pdf-all_items_item_5.txt
# 17          31 The UPS Store.pdf-all_items_item_5.txt
# 18         29 Planet Fitness.pdf-all_items_item_5.txt
# 19  25 Express Employment Professionals.pdf-all_it...
# 20              10 Taco Bell.pdf-all_items_item_5.txt
# 21        27 Jack In The Box.pdf-all_items_item_5.txt
# 22               37 Culver's.pdf-all_items_item_5.txt
# 23                 23 Arby's.PDF-all_items_item_5.txt
# 24           44 Home Instead.pdf-all_items_item_5.txt
# 25           39 Jersey Mikes.pdf-all_items_item_5.txt
# 26                14 Dunkin'.pdf-all_items_item_5.txt
# 27                  52 Midas.pdf-all_items_item_5.txt
# 28              35 Five Guys.pdf-all_items_item_5.txt
# 29            54 Homevesters.pdf-all_items_item_5.txt
# 30          49 Snap-On Tools.pdf-all_items_item_5.txt
# 31              12 Pizza Hut.pdf-all_items_item_5.txt
# 32                9 Circle K.pdf-all_items_item_5.txt
# 33                  13 REMAX.pdf-all_items_item_5.txt
# 34               41 Hardee's.pdf-all_items_item_5.txt
# 35            22 Papa John's.pdf-all_items_item_5.txt
# 36                   33 IHOP.pdf-all_items_item_5.txt
# 37  18 Popeyes Louisiana Kitchen.pdf-all_items_ite...
# 38            19 Dairy Queen.pdf-all_items_item_5.txt
# 39        50 Anytime Fitness.pdf-all_items_item_5.txt
# 40               38 Wingstop.pdf-all_items_item_5.txt
# 41                8 Domino's.pdf-all_items_item_5.txt
# 42           17 Panera Bread.pdf-all_items_item_5.txt
# 43            16 Tim Hortons.pdf-all_items_item_5.txt
# 44                11 Wendy's.pdf-all_items_item_5.txt
# 45  43 Vavoline Instant Oil Change.pdf-all_items_i...
# 46                  7 Subway.pdf-all_items_item_5.txt
# 47             51 Jiffy Lube.pdf-all_items_item_5.txt
# 48                26 Chili's.pdf-all_items_item_5.txt
# 49         21 Little Caesars.pdf-all_items_item_5.txt
#
#                   Generated Answer
# 0                       $ 35 , 000
# 1                       $ 45 , 000
# 2                       $ 35 , 000
# 3                       $ 35 , 000
# 4                       $ 35 , 000
# 5                       $ 90 , 000
# 6                 up to $ 30 , 000
# 7                       $ 25 , 000
# 8                       $ 12 , 500
# 9                       $ 45 , 000
# 10                       $ 5 , 000
# 11                      $ 10 , 000
# 12          fifty thousand dollars
# 13                      $ 45 , 000
# 14                      $ 25 , 000
# 15                      $ 25 , 000
# 16                              we
# 17                       $ 9 , 950
# 18                      $ 20 , 000
# 19                      $ 40 , 000
# 20                      $ 22 , 500
# 21                      $ 50 , 000
# 22                      $ 55 , 000
# 23                      $ 37 , 500
# 24                      $ 54 , 000
# 25                      $ 18 , 500
# 26               $ 0 to $ 90 , 000
# 27                      $ 35 , 000
# 28                      $ 25 , 000
# 29                      $ 85 , 000
# 30                      $ 16 , 000
# 31                      $ 25 , 000
# 32                      $ 25 , 000
# 33                      $ 25 , 000
# 34                      $ 15 , 000
# 35         $ 5 , 000 to $ 25 , 000
# 36      between $ 0 to $ 300 , 000
# 37                      $ 50 , 000
# 38                      $ 45 , 000
# 39                      $ 42 , 500
# 40                      $ 20 , 000
# 41               $ 0 to $ 10 , 000
# 42  thirty - five thousand dollars
# 43                      $ 25 , 000
# 44                      $ 20 , 000
# 45                      $ 30 , 000
# 46                       $ 1 , 000
# 47                      $ 35 , 000
# 48                      $ 60 , 000
# 49                      $ 20 , 000

# %%
pd1=pd.read_csv("orginaldata5.csv")
print("Columns in pd1:", pd1.columns)
print("Columns in df:", df.columns)
# Out:
# Columns in pd1: Index(['File Name ', 'True Initial value', 'factor 1', 'factor 2', 'factor 3',
#        'factor 4', ' factor 5 ', 'factor 6'],
#       dtype='object')
# Columns in df: Index(['File Name', 'Generated Answer'], dtype='object')

# %%
pd1.columns = pd1.columns.str.strip().str.lower()
df.columns = df.columns.str.strip().str.lower()

# Rename columns to match correctly
pd1.rename(columns={"file name": "filename"}, inplace=True)
df.rename(columns={"file name": "filename"}, inplace=True)

# 🔍 Debugging: Print column names again to verify
print("Columns in pd1 after renaming:", pd1.columns)
print("Columns in df after renaming:", df.columns)
# Out:
# Columns in pd1 after renaming: Index(['filename', 'true initial value', 'factor 1', 'factor 2', 'factor 3',
#        'factor 4', 'factor 5', 'factor 6'],
#       dtype='object')
# Columns in df after renaming: Index(['filename', 'generated answer'], dtype='object')

# %%
pd1.columns = pd1.columns.str.strip().str.lower()
df.columns = df.columns.str.strip().str.lower()

# Rename columns to ensure consistency
pd1.rename(columns={"file name": "filename"}, inplace=True)
df.rename(columns={"file name": "filename"}, inplace=True)

# Perform a **clean** left merge on "filename"
pd1 = pd1.merge(df, on="filename", how="left")

pd1
# Out:
#                                              filename     true initial value  \
# 0                   1 McDonald's.pdf-all_items_item_5                $45,000
# 1                      3 KFC.pdf-all_items_item_5.txt                $45,000
# 2              4 Burger King.pdf-all_items_item_5.txt                $50,000
# 3             5 Ace Hardware.pdf-all_items_item_5.txt                $10,000
# 4              6 Chick-fil-A.pdf-all_items_item_5.txt                     $0
# 5                   7 Subway.pdf-all_items_item_5.txt                $15,000
# 6                 8 Domino's.pdf-all_items_item_5.txt                $10,000
# 7                 9 Circle K.pdf-all_items_item_5.txt                $25,000
# 8               10 Taco Bell.pdf-all_items_item_5.txt                $22,500
# 9                 11 Wendy's.pdf-all_items_item_5.txt               $50,000.
# 10              12 Pizza Hut.pdf-all_items_item_5.txt                $25,000
# 11                  13 REMAX.pdf-all_items_item_5.txt  $35,000(high density)
# 12                14 Dunkin'.pdf-all_items_item_5.txt        $90,000( Type1)
# 13        15 Keller Williams.pdf-all_items_item_5.txt                $35,000
# 14            16 Tim Hortons.pdf-all_items_item_5.txt      $50,000(STANDARD)
# 15           17 Panera Bread.pdf-all_items_item_5.txt               $35,000
# 16  18 Popeyes Louisiana Kitchen.pdf-all_items_ite...                $50,000
# 17            19 Dairy Queen.pdf-all_items_item_5.txt                $45,000
# 18         20 Sonic Drive-In.pdf-all_items_item_5.txt   $45,000(traditional)
# 19         21 Little Caesars.pdf-all_items_item_5.txt                $20,000
# 20            22 Papa John's.pdf-all_items_item_5.txt           $5000-$25000
# 21                 23 Arby's.PDF-all_items_item_5.txt      $37,500(standard)
# 22              24 Applebees.pdf-all_items_item_5.txt                $35,000
# 23  25 Express Employment Professionals.pdf-all_it...                $40,000
# 24                26 Chili's.pdf-all_items_item_5.txt                $60,000
# 25        27 Jack In The Box.pdf-all_items_item_5.txt                $50,000
# 26     28 Buffalo Wild Wings.pdf-all_items_item_5.txt                $30,000
# 27         29 Planet Fitness.pdf-all_items_item_5.txt                $20,000
# 28     30 Berkshire Hathaway.pdf-all_items_item_5.txt                $25,000
# 29          31 The UPS Store.pdf-all_items_item_5.txt                $29,950
# 30                32 Servpro.pdf-all_items_item_5.txt                $90,000
# 31                   33 IHOP.pdf-all_items_item_5.txt        $50,000(single)
# 32              35 Five Guys.pdf-all_items_item_5.txt                $25,000
# 33                36 Denny's.pdf-all_items_item_5.txt                $30,000
# 34               37 Culver's.pdf-all_items_item_5.txt                $55,000
# 35               38 Wingstop.pdf-all_items_item_5.txt                $20,000
# 36           39 Jersey Mikes.pdf-all_items_item_5.txt                $18,500
# 37         40 Paris Baguette.pdf-all_items_item_5.txt                $50,000
# 38               41 Hardee's.pdf-all_items_item_5.txt                $25,000
# 39           42 Jimmy John's.pdf-all_items_item_5.txt                $35,000
# 40  43 Vavoline Instant Oil Change.pdf-all_items_i...  $30,000(first center)
# 41           44 Home Instead.pdf-all_items_item_5.txt                $54,000
# 42                 45 Zaxbys.pdf-all_items_item_5.txt                $35,000
# 43             46 Carl's Jr..pdf-all_items_item_5.txt                $25,000
# 44         47 Baskin Robbins.pdf-all_items_item_5.txt                $25,000
# 45          49 Snap-On Tools.pdf-all_items_item_5.txt           $8,000 (min)
# 46        50 Anytime Fitness.pdf-all_items_item_5.txt                $42,500
# 47             51 Jiffy Lube.pdf-all_items_item_5.txt   $35,000 (new center)
# 48                  52 Midas.pdf-all_items_item_5.txt   $35,000 (new center)
# 49            54 Homevesters.pdf-all_items_item_5.txt         $85,000 (Full)
#
#                               factor 1                          factor 2  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2            $25,000 (conditional FSS)          $15,000 (shorter period)
# 3                  $5,000 (stock Fee )          $5,000(waivable adminfee
# 4                                  NaN                               NaN
# 5                   $7,500(conditions)   $5000 (satellite franchise fee)
# 6      $1500 (exisitng store transfer)                               NaN
# 7        $15,000 per store(2-5 stores)       $10,000 per store(6-9store)
# 8                                  NaN                               NaN
# 9                                  NaN                               NaN
# 10                                 NaN                               NaN
# 11                $17,500(low density)               $25,000(commercial)
# 12                     $80,000(type 2)                    $70,000(type3)
# 13                                 NaN                               NaN
# 14               $25,000(NON STANDARD)                               NaN
# 15                                 NaN                               NaN
# 16                                 NaN                               NaN
# 17                                 NaN                               NaN
# 18            $22,500(non traditional)                               NaN
# 19                                 NaN                               NaN
# 20                                 NaN                               NaN
# 21              $18,750 (non standard)                               NaN
# 22                                 NaN                               NaN
# 23                                 NaN                               NaN
# 24                       $40,000 (UDP)                               NaN
# 25                                 NaN                               NaN
# 26          $45,000(20 year agreement)                               NaN
# 27                                 NaN                               NaN
# 28                                 NaN                               NaN
# 29            $19,950(under conditons)               $9,950 (Rural Area)
# 30                                 NaN                               NaN
# 31                      $40,000(MULTI)              $0 TO $300,000(IHOP)
# 32                                 NaN                               NaN
# 33            $10,000(10 YEAR AGREEME)                               NaN
# 34          $30,000(mentoring program)         $45,000(veteran discount)
# 35                     $5,000(veteran)                               NaN
# 36                                 NaN                               NaN
# 37            $40,000(multiple stores)                               NaN
# 38         $15,000(development agreem)                               NaN
# 39                                 NaN                               NaN
# 40              $20,000(second center)  $5,000(second center conversion)
# 41                                 NaN                               NaN
# 42                                 NaN                               NaN
# 43                                 NaN                               NaN
# 44  $12,500 (gas station for 10 years)            $6,250 at SDO location
# 45                        $16,000(max)                               NaN
# 46                                 NaN                               NaN
# 47          $17,500 (converted center)                               NaN
# 48          $17,500 (converted center)                               NaN
# 49                  $39,000(associate)  $76,500(veteran -full franchise)
#
#                             factor 3                      factor 4  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# 5   $1000 (short term satellite fee)                           NaN
# 6                                NaN                           NaN
# 7               $7,500(10-19 stores)            $5,000 (20 stores)
# 8                                NaN                           NaN
# 9                                NaN                           NaN
# 10                               NaN                           NaN
# 11                               NaN                           NaN
# 12                   $60,000(type 4)               $50,000(type 5)
# 13                               NaN                           NaN
# 14                               NaN                           NaN
# 15                               NaN                           NaN
# 16                               NaN                           NaN
# 17                               NaN                           NaN
# 18                               NaN                           NaN
# 19                               NaN                           NaN
# 20                               NaN                           NaN
# 21                               NaN                           NaN
# 22                               NaN                           NaN
# 23                               NaN                           NaN
# 24                               NaN                           NaN
# 25                               NaN                           NaN
# 26                               NaN                           NaN
# 27                               NaN                           NaN
# 28                               NaN                           NaN
# 29                               NaN                           NaN
# 30                               NaN                           NaN
# 31                               NaN                           NaN
# 32                               NaN                           NaN
# 33                               NaN                           NaN
# 34                               NaN                           NaN
# 35                               NaN                           NaN
# 36                               NaN                           NaN
# 37                               NaN                           NaN
# 38                               NaN                           NaN
# 39                               NaN                           NaN
# 40          $5,000(thrid and beyond)                           NaN
# 41                               NaN                           NaN
# 42                               NaN                           NaN
# 43                               NaN                           NaN
# 44                   $10,000 (Combo)                           NaN
# 45                               NaN                           NaN
# 46                               NaN                           NaN
# 47                               NaN                           NaN
# 48                               NaN                           NaN
# 49        $35,100(veteran associate)  $68,000 Multi full franchise
#
#                    factor 5  factor 6                generated answer
# 0                       NaN       NaN                             NaN
# 1                       NaN       NaN                      $ 45 , 000
# 2                       NaN       NaN                      $ 25 , 000
# 3                       NaN       NaN                       $ 5 , 000
# 4                       NaN       NaN                              we
# 5                       NaN       NaN                       $ 1 , 000
# 6                       NaN       NaN               $ 0 to $ 10 , 000
# 7                       NaN       NaN                      $ 25 , 000
# 8                       NaN       NaN                      $ 22 , 500
# 9                       NaN       NaN                      $ 20 , 000
# 10                      NaN       NaN                      $ 25 , 000
# 11                      NaN       NaN                      $ 25 , 000
# 12          $40,000(type 6)       NaN               $ 0 to $ 90 , 000
# 13                      NaN       NaN                      $ 35 , 000
# 14                      NaN       NaN                      $ 25 , 000
# 15                      NaN       NaN  thirty - five thousand dollars
# 16                      NaN       NaN                      $ 50 , 000
# 17                      NaN       NaN                      $ 45 , 000
# 18                      NaN       NaN                up to $ 30 , 000
# 19                      NaN       NaN                      $ 20 , 000
# 20                      NaN       NaN         $ 5 , 000 to $ 25 , 000
# 21                      NaN       NaN                      $ 37 , 500
# 22                      NaN       NaN                      $ 35 , 000
# 23                      NaN       NaN                      $ 40 , 000
# 24                      NaN       NaN                      $ 60 , 000
# 25                      NaN       NaN                      $ 50 , 000
# 26                      NaN       NaN                      $ 45 , 000
# 27                      NaN       NaN                      $ 20 , 000
# 28                      NaN       NaN                      $ 25 , 000
# 29                      NaN       NaN                       $ 9 , 950
# 30                      NaN       NaN                      $ 90 , 000
# 31                      NaN       NaN      between $ 0 to $ 300 , 000
# 32                      NaN       NaN                      $ 25 , 000
# 33                      NaN       NaN                      $ 10 , 000
# 34                      NaN       NaN                      $ 55 , 000
# 35                      NaN       NaN                      $ 20 , 000
# 36                      NaN       NaN                      $ 18 , 500
# 37                      NaN       NaN          fifty thousand dollars
# 38                      NaN       NaN                      $ 15 , 000
# 39                      NaN       NaN                      $ 35 , 000
# 40                      NaN       NaN                      $ 30 , 000
# 41                      NaN       NaN                      $ 54 , 000
# 42                      NaN       NaN                      $ 35 , 000
# 43                      NaN       NaN                      $ 25 , 000
# 44                      NaN       NaN                      $ 12 , 500
# 45                      NaN       NaN                      $ 16 , 000
# 46                      NaN       NaN                      $ 42 , 500
# 47                      NaN       NaN                      $ 35 , 000
# 48                      NaN       NaN                      $ 35 , 000
# 49  $31,200 Multi associate       NaN                      $ 85 , 000

# %%
column_order = ["filename", "generated answer"] + [col for col in pd1.columns if col not in ["filename", "generated answer"]]
pd1 = pd1[column_order]  # Apply new order

# %%
pd1
pd1.to_csv("5_final_dataframe.csv", index=False)

# %%
pd1
# Out:
#                                              filename  \
# 0                   1 McDonald's.pdf-all_items_item_5
# 1                      3 KFC.pdf-all_items_item_5.txt
# 2              4 Burger King.pdf-all_items_item_5.txt
# 3             5 Ace Hardware.pdf-all_items_item_5.txt
# 4              6 Chick-fil-A.pdf-all_items_item_5.txt
# 5                   7 Subway.pdf-all_items_item_5.txt
# 6                 8 Domino's.pdf-all_items_item_5.txt
# 7                 9 Circle K.pdf-all_items_item_5.txt
# 8               10 Taco Bell.pdf-all_items_item_5.txt
# 9                 11 Wendy's.pdf-all_items_item_5.txt
# 10              12 Pizza Hut.pdf-all_items_item_5.txt
# 11                  13 REMAX.pdf-all_items_item_5.txt
# 12                14 Dunkin'.pdf-all_items_item_5.txt
# 13        15 Keller Williams.pdf-all_items_item_5.txt
# 14            16 Tim Hortons.pdf-all_items_item_5.txt
# 15           17 Panera Bread.pdf-all_items_item_5.txt
# 16  18 Popeyes Louisiana Kitchen.pdf-all_items_ite...
# 17            19 Dairy Queen.pdf-all_items_item_5.txt
# 18         20 Sonic Drive-In.pdf-all_items_item_5.txt
# 19         21 Little Caesars.pdf-all_items_item_5.txt
# 20            22 Papa John's.pdf-all_items_item_5.txt
# 21                 23 Arby's.PDF-all_items_item_5.txt
# 22              24 Applebees.pdf-all_items_item_5.txt
# 23  25 Express Employment Professionals.pdf-all_it...
# 24                26 Chili's.pdf-all_items_item_5.txt
# 25        27 Jack In The Box.pdf-all_items_item_5.txt
# 26     28 Buffalo Wild Wings.pdf-all_items_item_5.txt
# 27         29 Planet Fitness.pdf-all_items_item_5.txt
# 28     30 Berkshire Hathaway.pdf-all_items_item_5.txt
# 29          31 The UPS Store.pdf-all_items_item_5.txt
# 30                32 Servpro.pdf-all_items_item_5.txt
# 31                   33 IHOP.pdf-all_items_item_5.txt
# 32              35 Five Guys.pdf-all_items_item_5.txt
# 33                36 Denny's.pdf-all_items_item_5.txt
# 34               37 Culver's.pdf-all_items_item_5.txt
# 35               38 Wingstop.pdf-all_items_item_5.txt
# 36           39 Jersey Mikes.pdf-all_items_item_5.txt
# 37         40 Paris Baguette.pdf-all_items_item_5.txt
# 38               41 Hardee's.pdf-all_items_item_5.txt
# 39           42 Jimmy John's.pdf-all_items_item_5.txt
# 40  43 Vavoline Instant Oil Change.pdf-all_items_i...
# 41           44 Home Instead.pdf-all_items_item_5.txt
# 42                 45 Zaxbys.pdf-all_items_item_5.txt
# 43             46 Carl's Jr..pdf-all_items_item_5.txt
# 44         47 Baskin Robbins.pdf-all_items_item_5.txt
# 45          49 Snap-On Tools.pdf-all_items_item_5.txt
# 46        50 Anytime Fitness.pdf-all_items_item_5.txt
# 47             51 Jiffy Lube.pdf-all_items_item_5.txt
# 48                  52 Midas.pdf-all_items_item_5.txt
# 49            54 Homevesters.pdf-all_items_item_5.txt
#
#                   generated answer     true initial value  \
# 0                              NaN                $45,000
# 1                       $ 45 , 000                $45,000
# 2                       $ 25 , 000                $50,000
# 3                        $ 5 , 000                $10,000
# 4                               we                     $0
# 5                        $ 1 , 000                $15,000
# 6                $ 0 to $ 10 , 000                $10,000
# 7                       $ 25 , 000                $25,000
# 8                       $ 22 , 500                $22,500
# 9                       $ 20 , 000               $50,000.
# 10                      $ 25 , 000                $25,000
# 11                      $ 25 , 000  $35,000(high density)
# 12               $ 0 to $ 90 , 000        $90,000( Type1)
# 13                      $ 35 , 000                $35,000
# 14                      $ 25 , 000      $50,000(STANDARD)
# 15  thirty - five thousand dollars               $35,000
# 16                      $ 50 , 000                $50,000
# 17                      $ 45 , 000                $45,000
# 18                up to $ 30 , 000   $45,000(traditional)
# 19                      $ 20 , 000                $20,000
# 20         $ 5 , 000 to $ 25 , 000           $5000-$25000
# 21                      $ 37 , 500      $37,500(standard)
# 22                      $ 35 , 000                $35,000
# 23                      $ 40 , 000                $40,000
# 24                      $ 60 , 000                $60,000
# 25                      $ 50 , 000                $50,000
# 26                      $ 45 , 000                $30,000
# 27                      $ 20 , 000                $20,000
# 28                      $ 25 , 000                $25,000
# 29                       $ 9 , 950                $29,950
# 30                      $ 90 , 000                $90,000
# 31      between $ 0 to $ 300 , 000        $50,000(single)
# 32                      $ 25 , 000                $25,000
# 33                      $ 10 , 000                $30,000
# 34                      $ 55 , 000                $55,000
# 35                      $ 20 , 000                $20,000
# 36                      $ 18 , 500                $18,500
# 37          fifty thousand dollars                $50,000
# 38                      $ 15 , 000                $25,000
# 39                      $ 35 , 000                $35,000
# 40                      $ 30 , 000  $30,000(first center)
# 41                      $ 54 , 000                $54,000
# 42                      $ 35 , 000                $35,000
# 43                      $ 25 , 000                $25,000
# 44                      $ 12 , 500                $25,000
# 45                      $ 16 , 000           $8,000 (min)
# 46                      $ 42 , 500                $42,500
# 47                      $ 35 , 000   $35,000 (new center)
# 48                      $ 35 , 000   $35,000 (new center)
# 49                      $ 85 , 000         $85,000 (Full)
#
#                               factor 1                          factor 2  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2            $25,000 (conditional FSS)          $15,000 (shorter period)
# 3                  $5,000 (stock Fee )          $5,000(waivable adminfee
# 4                                  NaN                               NaN
# 5                   $7,500(conditions)   $5000 (satellite franchise fee)
# 6      $1500 (exisitng store transfer)                               NaN
# 7        $15,000 per store(2-5 stores)       $10,000 per store(6-9store)
# 8                                  NaN                               NaN
# 9                                  NaN                               NaN
# 10                                 NaN                               NaN
# 11                $17,500(low density)               $25,000(commercial)
# 12                     $80,000(type 2)                    $70,000(type3)
# 13                                 NaN                               NaN
# 14               $25,000(NON STANDARD)                               NaN
# 15                                 NaN                               NaN
# 16                                 NaN                               NaN
# 17                                 NaN                               NaN
# 18            $22,500(non traditional)                               NaN
# 19                                 NaN                               NaN
# 20                                 NaN                               NaN
# 21              $18,750 (non standard)                               NaN
# 22                                 NaN                               NaN
# 23                                 NaN                               NaN
# 24                       $40,000 (UDP)                               NaN
# 25                                 NaN                               NaN
# 26          $45,000(20 year agreement)                               NaN
# 27                                 NaN                               NaN
# 28                                 NaN                               NaN
# 29            $19,950(under conditons)               $9,950 (Rural Area)
# 30                                 NaN                               NaN
# 31                      $40,000(MULTI)              $0 TO $300,000(IHOP)
# 32                                 NaN                               NaN
# 33            $10,000(10 YEAR AGREEME)                               NaN
# 34          $30,000(mentoring program)         $45,000(veteran discount)
# 35                     $5,000(veteran)                               NaN
# 36                                 NaN                               NaN
# 37            $40,000(multiple stores)                               NaN
# 38         $15,000(development agreem)                               NaN
# 39                                 NaN                               NaN
# 40              $20,000(second center)  $5,000(second center conversion)
# 41                                 NaN                               NaN
# 42                                 NaN                               NaN
# 43                                 NaN                               NaN
# 44  $12,500 (gas station for 10 years)            $6,250 at SDO location
# 45                        $16,000(max)                               NaN
# 46                                 NaN                               NaN
# 47          $17,500 (converted center)                               NaN
# 48          $17,500 (converted center)                               NaN
# 49                  $39,000(associate)  $76,500(veteran -full franchise)
#
#                             factor 3                      factor 4  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# 5   $1000 (short term satellite fee)                           NaN
# 6                                NaN                           NaN
# 7               $7,500(10-19 stores)            $5,000 (20 stores)
# 8                                NaN                           NaN
# 9                                NaN                           NaN
# 10                               NaN                           NaN
# 11                               NaN                           NaN
# 12                   $60,000(type 4)               $50,000(type 5)
# 13                               NaN                           NaN
# 14                               NaN                           NaN
# 15                               NaN                           NaN
# 16                               NaN                           NaN
# 17                               NaN                           NaN
# 18                               NaN                           NaN
# 19                               NaN                           NaN
# 20                               NaN                           NaN
# 21                               NaN                           NaN
# 22                               NaN                           NaN
# 23                               NaN                           NaN
# 24                               NaN                           NaN
# 25                               NaN                           NaN
# 26                               NaN                           NaN
# 27                               NaN                           NaN
# 28                               NaN                           NaN
# 29                               NaN                           NaN
# 30                               NaN                           NaN
# 31                               NaN                           NaN
# 32                               NaN                           NaN
# 33                               NaN                           NaN
# 34                               NaN                           NaN
# 35                               NaN                           NaN
# 36                               NaN                           NaN
# 37                               NaN                           NaN
# 38                               NaN                           NaN
# 39                               NaN                           NaN
# 40          $5,000(thrid and beyond)                           NaN
# 41                               NaN                           NaN
# 42                               NaN                           NaN
# 43                               NaN                           NaN
# 44                   $10,000 (Combo)                           NaN
# 45                               NaN                           NaN
# 46                               NaN                           NaN
# 47                               NaN                           NaN
# 48                               NaN                           NaN
# 49        $35,100(veteran associate)  $68,000 Multi full franchise
#
#                    factor 5  factor 6
# 0                       NaN       NaN
# 1                       NaN       NaN
# 2                       NaN       NaN
# 3                       NaN       NaN
# 4                       NaN       NaN
# 5                       NaN       NaN
# 6                       NaN       NaN
# 7                       NaN       NaN
# 8                       NaN       NaN
# 9                       NaN       NaN
# 10                      NaN       NaN
# 11                      NaN       NaN
# 12          $40,000(type 6)       NaN
# 13                      NaN       NaN
# 14                      NaN       NaN
# 15                      NaN       NaN
# 16                      NaN       NaN
# 17                      NaN       NaN
# 18                      NaN       NaN
# 19                      NaN       NaN
# 20                      NaN       NaN
# 21                      NaN       NaN
# 22                      NaN       NaN
# 23                      NaN       NaN
# 24                      NaN       NaN
# 25                      NaN       NaN
# 26                      NaN       NaN
# 27                      NaN       NaN
# 28                      NaN       NaN
# 29                      NaN       NaN
# 30                      NaN       NaN
# 31                      NaN       NaN
# 32                      NaN       NaN
# 33                      NaN       NaN
# 34                      NaN       NaN
# 35                      NaN       NaN
# 36                      NaN       NaN
# 37                      NaN       NaN
# 38                      NaN       NaN
# 39                      NaN       NaN
# 40                      NaN       NaN
# 41                      NaN       NaN
# 42                      NaN       NaN
# 43                      NaN       NaN
# 44                      NaN       NaN
# 45                      NaN       NaN
# 46                      NaN       NaN
# 47                      NaN       NaN
# 48                      NaN       NaN
# 49  $31,200 Multi associate       NaN
